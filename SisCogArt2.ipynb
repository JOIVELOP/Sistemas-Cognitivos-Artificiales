# %% [markdown]
# <a href="https://colab.research.google.com/github/JOIVELOP/Sistemas-Cognitivos-Artificiales/blob/main/SisCogArt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# <h1> Dataset Boston Housing </h1>

# %% [markdown]
# El dataset de *Boston Housing* está compuesto de 506 registros del censo de 1970.
#
# Las variables que definen el problema son:
#
# <dl>
#   <dt><b>Crime Rate</b> (<i>crim</i>)</dt>
#     <dd>Crimen per cápita por ciudad</dd>
#   <dt><b>Residential Land Zones</b> (<i>zn</i>)</dt>
#     <dd>Proporción de terrenos residenciales divididos en zonas para lotes de más de 25,000 pies cuadrados (aproximadamente 2322.576 m<sup>2</sup>)</dd>
#   <dt><b>Non-retail Business Acres</b> (<i>indus</i>)</dt>
#     <dd>Proporción de acres (0.40 ha) de negocios no minoristas por ciudad</dd>
#   <dt><b>Charles River tract bounds</b> (<i>chas</i>)</dt>
#     <dd>Variable ficticia de Charles River (= 1 si colinda con el río, 0 de lo contrario)</dd>
#   <dt><b>N.O. Concentration</b> (<i>nox</i>)</dt>
#     <dd>Concentración de óxidos nítricos (partes por 10 millones)</dd>
#   <dt><b>No. of Rooms</b> (<i>rm</i>)</dt>
#     <dd>Número promedio de habitaciones por vivienda</dd>
#   <dt><b>Age</b> (<i>age</i>)</dt>
#     <dd>Proporción de unidades ocupadas por sus propietarios construidas antes de 1940</dd>
#   <dt><b>Distance to Employment</b> (<i>dis</i>)</dt>
#     <dd>Distancias desproporcionadas a cinco centros de empleo de Boston</dd>
#   <dt><b>Highway Accessibility</b> (<i>rad</i>)
#     <dd>Índice de accesibilidad a las autopistas</dd>
#   <dt><b>Property Tax Rate</b> (<i>tax</i>)
#     <dd>Tasa de impuesto a la propiedad de valor completo por USD 10,000</dd>
#   <dt><b>Pupil Teacher Ratio</b> (<i>ptratio</i>)</dt>
#     <dd>Colegios por localidad</dd>
#   <dt><b>B</b>
#     <dd>Proporción de negros por ciudad</dd>
#   <dt><b>% Lower Income</b> (<i>lstat</i>)
#     <dd>Porcentaje de estado inferior de la población</dd>
#   <dt><b>price</b><dt>
#     <dd>Valor mediano de las viviendas ocupadas por sus propietarios en USD 1000</dd>
# </dl>

# %% [markdown]
# <h2> Cargando el dataset Boston housing </h2>

# %%
# Se importa el dataset Boston housing
boston_housing = tf.keras.datasets.boston_housing

# Se cargan los conjuntos de entrenamiento (*_train_whole) y de validación (*_test) en variables separadas
(X_train_whole, y_train_whole), (X_test, y_test) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
# Impresión del número de muestras para el conjunto de entrenamiento y de validación

print(f'Número de muestras del conjunto de entrenamiento {X_train_whole.shape}')
print(f'Número de muestras del conjunto de prueba {X_test.shape}')
# Out:
# Número de muestras del conjunto de entrenamiento (404, 13)
# Número de muestras del conjunto de prueba (102, 13)

# %% [markdown]
# ### Se colocan los datos en un dataframe

# %%
import pandas as pd
import numpy as np

# Nombres de las variables
# Nombre largo
variables_boston_housing = ['Crime Rate', 'Residential Land Zones', 'Non-retail Business Acres', 'Charles River tract bounds', 'N.O. Concentration',
                '# of Rooms', 'Age', 'Distance to Employment', 'Highway Accessibility', 'Property Tax Rate', 'Pupil Teacher Ratio', 'B', '% Lower Income',
                'Housing value']
# Nombre corto
short_variables = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'B', 'lstat', 'price']

# Se inserta la variable independiente (y_train_whole) al final del las variables del problema
train_whole = np.insert(X_train_whole, -1, y_train_whole, axis=1)

# Se genera un dataframe con la información del conjunto de entrenamiento
df_train = pd.DataFrame(train_whole, columns = short_variables)

# %%
df_train.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis   rad    tax  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
#
#    ptratio       B  lstat  price
# 0     21.0  396.90   15.2  18.72
# 1     14.7  395.38   42.3   3.11
# 2     20.2  375.52   50.0   3.26
# 3     20.2  396.90   21.1   8.01
# 4     20.2  391.43   17.7  14.65

# %% [markdown]
# #### Valores nulos
#
# En caso de existir valores nulos, las soluciones más comunes son:
# 1. Eliminar las muestras (filas) o características (columnas) que contengan valores nulos.
# 2. Reemplazar por un valor constante, tal como la media, mediana, moda, etc.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     404 non-null    float64
#  1   zn       404 non-null    float64
#  2   indus    404 non-null    float64
#  3   chas     404 non-null    float64
#  4   nox      404 non-null    float64
#  5   rm       404 non-null    float64
#  6   age      404 non-null    float64
#  7   dis      404 non-null    float64
#  8   rad      404 non-null    float64
#  9   tax      404 non-null    float64
#  10  ptratio  404 non-null    float64
#  11  B        404 non-null    float64
#  12  lstat    404 non-null    float64
#  13  price    404 non-null    float64
# dtypes: float64(14)
# memory usage: 44.3 KB

# %%
df_train.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# B          0
# lstat      0
# price      0
# dtype: int64

# %% [markdown]
# <h3>Análisis de los datos</h3>

# %%
# Se calcula la información estadística, tal como media, desviación estándar, percentil, etc, de cada una de las columnas del dataframe
df_train.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.745111   11.480198   11.104431    0.061881    0.557356    6.267082
# std      9.240734   23.767711    6.811308    0.241238    0.117293    0.709788
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081437    0.000000    5.130000    0.000000    0.453000    5.874750
# 50%      0.268880    0.000000    9.690000    0.000000    0.538000    6.198500
# 75%      3.674808   12.500000   18.100000    0.000000    0.631000    6.609000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.725000
#
#               age         dis         rad         tax     ptratio           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.010644    3.740271    9.440594  405.898515   18.475990  354.783168
# std     27.940665    2.030215    8.698360  166.374543    2.200382   94.111148
# min      2.900000    1.129600    1.000000  188.000000   12.600000    0.320000
# 25%     45.475000    2.077100    4.000000  279.000000   17.225000  374.672500
# 50%     78.500000    3.142300    5.000000  330.000000   19.100000  391.250000
# 75%     94.100000    5.118000   24.000000  666.000000   20.200000  396.157500
# max    100.000000   10.710300   24.000000  711.000000   22.000000  396.900000
#
#             lstat       price
# count  404.000000  404.000000
# mean    22.395050   12.740817
# std      9.210442    7.254545
# min      5.000000    1.730000
# 25%     16.675000    6.890000
# 50%     20.750000   11.395000
# 75%     24.800000   17.092500
# max     50.000000   37.970000

# %% [markdown]
# ### Visualización

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# Se grafican los diagramas de caja de cada una de las columnas del dataframe
boxplot = df_train[short_variables[:-1]].boxplot(figsize=(15,7))

plt.show()

# %%
#
sb.histplot(np.concatenate((y_train_whole, y_test), axis=0), kde=True)
plt.show()

# %%
#
sb.boxplot(df_train["price"], orient='h')
plt.show()

# %% [markdown]
# ### Correlación entre las variables

# %%
correlation = df_train.corr()
print(correlation.loc['price'])

# Se calcula la matriz de correlación por pares de columnas, excluyendo los valores nulos
fig = plt.figure(figsize=(10, 10))

matriz_corr = df_train.corr()
# Mapa de calor de la matriz de correlación
ax = sb.heatmap(matriz_corr, linewidths=1.5, linecolor='white',
                cmap='coolwarm', annot=True)
plt.show()
# Out:
# crim       0.434384
# zn        -0.415237
# indus      0.603129
# chas      -0.011017
# nox        0.592994
# rm        -0.610844
# age        0.590898
# dis       -0.507075
# rad        0.490250
# tax        0.534752
# ptratio    0.365873
# B         -0.376081
# lstat     -0.730793
# price      1.000000
# Name: price, dtype: float64

# %%
# Revisamos los aChecking the scatter plot with the most correlated features
plt.figure(figsize = (20,5))
features = ['lstat','rm','ptratio']
for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = df_train[col]
    y = df_train.price
    print(i)
    print(col)
    plt.scatter(x, y, marker='o')
    plt.title("Variación de los precios de las casas")
    plt.xlabel(col)
    plt.ylabel("Precios de las casas en USD$1000")
plt.show()
# Out:
# 0
# lstat
# 1
# rm
# 2
# ptratio

# %% [markdown]
# ## Dividir el dataset

# %%
from sklearn.model_selection import train_test_split

# Se divide el dataset en 3 partes:
# 1. Train (entrenamiento)
# 2. Validation (validacion)
# 3. Test (prueba)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_whole, y_train_whole, test_size = 0.2, random_state = 4)
#Quitar la normalización de datos

# %% [markdown]
# ## Normalización de datos

# %%
import numpy as np
from sklearn.preprocessing import normalize

Xtrain_norm = normalize(X_train_whole, axis=0)
Xvalid_norm = normalize(X_valid, axis=0)
X_test_norm = normalize(X_test, axis=0)

# %%
X_test_norm.shape
# Out:
# (102, 13)

# %% [markdown]
# ## Entrenamiento de la red neuronal multicapa

# %% [markdown]
# ### Definición del modelo
#
# **Keras** es una librería que funciona sobre **Tensorflow** y permite definir modelos de manera sencilla.
#
# **Modelo secuencial**<br>
#
# Modelo que se compone de una pila de capas, donde cada capa tiene un tensor (arreglo) de entrada y un tensor de salida. Se usa
#
# <center>
# <b>keras.Sequential()</b>
# </center>
#
# para definir un modelo secuencial
#
# La arquitectura del modelo va a contener la siguiente capa:
# <dl>
#   <dt><b>Dense</b></dt>
#   <dd>Capa de neuronas densamente conectada<br>
#      Argumentos:
#      <ul>
#       <li><b>units</b> Valor entero positivo e indica la dimensionalidad de salida
#      <li><b>activation=None</b> Función de activación, por default "linear" (a(x)=x)
#      </ul>
#   </dd>
# </dl>
#
# https://keras.io/api/layers/core_layers/dense/
#
# **Funciones de activación**<br>
#
# <dl>
#     <dt><b>relu</b></dt>
#         <dd>Si X>0 devuelve X, si no, devuelve 0</dd>
#     <dt><b>softmax</b></dt>
#         <dd>Generalmente se emplea en la última capa de una red de clasificación (más de 2 clases), debido a que el resultado se puede interpretar como una distribución de probabilidad.</dd>
#     <dt><b>sigmoid</b></dt>
#         <dd>Función de activación sigmoide, la cual retorna valores entre 0 y 1. Además, esta función es equivalente softmax de dos clases (clasificación binaria)</dd>
# </dl>
#
# https://keras.io/api/layers/activations/

# %%
# Importando librerias para definir la arquitectura
import keras
from keras.layers import Dense
from keras.models import Sequential

# %%
# Definición del modelo
model = Sequential()

model.add(Dense(128, activation='relu', name="Entrada", input_dim =13))
model.add(Dense(64, activation='relu', name="Piso1"))
model.add(Dense(32, activation='relu', name="Piso2"))
model.add(Dense(16, activation='relu', name="Piso3"))
model.add(Dense(8, activation='relu', name="Piso4"))
model.add(Dense(1, name="Salida"))

# %%
#Cantidad de capas(muestra)
#Cuántos parámetros se van a entrenar
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Entrada (Dense)             (None, 128)               1792
#
#  Piso1 (Dense)               (None, 64)                8256
#
#  Piso2 (Dense)               (None, 32)                2080
#
#  Piso3 (Dense)               (None, 16)                528
#
#  Piso4 (Dense)               (None, 8)                 136
#
#  Salida (Dense)              (None, 1)                 9
#
# =================================================================
# Total params: 12801 (50.00 KB)
# Trainable params: 12801 (50.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# !pip install pydot
tf.keras.utils.plot_model(model, to_file="prueba.png", show_shapes=True)
#El establecer a las neuronas es: 2^n (Usualmente)

# %% [markdown]
# ### Compilación del modelo
#
# <center>
# <b>model.compile</b>
# </center>
#
# Parámetros:
#
# <dl>
#     <dt><b>optimizer</b></dt>
#         <dd>Algoritmo de optimización que se utiliza para entrenar la red. El descenso del gradiente estocástico (sgd) es un ejemplo de estos algoritmos.(https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)</dd>
#     <dt><b>loss</b></dt>
#         <dd>La función de pérdida se emplea para evaluar la red durante el entrenamiento y por lo tanto su valor se minimiza, un ejemplo es mean_absolute_error (https://www.tensorflow.org/api_docs/python/tf/keras/losses)</dd>
#     <dt><b>metrics</b></dt>
#         <dd>Métricas para la evaluación (desempeño) del modelo, después de que se entreno. Por ejemplo mse (https://www.tensorflow.org/api_docs/python/tf/keras/metrics)</dd>
# </dl>

# %%
model.compile(
    #Optimizador
    optimizer = 'Adam',
    #Pérdida
    loss = 'mean_squared_error',
    #Métrica
    metrics=['mae'] #'mse' o 'mape'
)

# %% [markdown]
# ### Entrenamiento del modelo
#
# <center>
#     <b>model.fit</b>
# </center>
#
# Entrena el modelo durante un número de épocas (iteraciones en el dataset)
#
# Parámetros
#
# *   <b>epochs</b>. Número de epocas para entrenar el modelo
# *   <b>validation_data</b>. Conjunto de datos que se emplean para evaluar la perdida al final de cada epoca.
# *   <b>batch_size</b>. Número de muestras para actualización del gradiente
# *   <b>verbose</b>. Salida del proceso de entrenamiento (0, 1, 2)

# %%
history = model.fit(
    Xtrain_norm, y_train_whole,
    epochs = 100,
    validation_data = (Xvalid_norm, y_valid),)
    #batch_size=10)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 20ms/step - loss: 580.0587 - mae: 22.2558 - val_loss: 614.5333 - val_mae: 22.7496
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 553.1649 - mae: 21.6452 - val_loss: 552.7886 - val_mae: 21.3079
# Epoch 3/100
# 13/13 [==============================] - 0s 5ms/step - loss: 479.0377 - mae: 19.7896 - val_loss: 386.0584 - val_mae: 16.8837
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 299.7000 - mae: 14.4717 - val_loss: 140.3478 - val_mae: 9.0346
# Epoch 5/100
# 13/13 [==============================] - 0s 5ms/step - loss: 112.3891 - mae: 7.9072 - val_loss: 326.9767 - val_mae: 15.4526
# Epoch 6/100
# 13/13 [==============================] - 0s 5ms/step - loss: 105.7561 - mae: 7.9518 - val_loss: 152.2357 - val_mae: 10.3364
# Epoch 7/100
# 13/13 [==============================] - 0s 6ms/step - loss: 90.1808 - mae: 6.8488 - val_loss: 155.5150 - val_mae: 10.6075
# Epoch 8/100
# 13/13 [==============================] - 0s 7ms/step - loss: 83.8582 - mae: 6.6637 - val_loss: 147.8916 - val_mae: 10.3934
# Epoch 9/100
# 13/13 [==============================] - 0s 5ms/step - loss: 79.5213 - mae: 6.4383 - val_loss: 135.5595 - val_mae: 9.9645
# Epoch 10/100
# 13/13 [==============================] - 0s 5ms/step - loss: 74.9054 - mae: 6.3048 - val_loss: 133.3382 - val_mae: 9.9550
# Epoch 11/100
# 13/13 [==============================] - 0s 7ms/step - loss: 71.0084 - mae: 6.1400 - val_loss: 112.5805 - val_mae: 8.9175
# Epoch 12/100
# 13/13 [==============================] - 0s 6ms/step - loss: 67.3672 - mae: 5.8431 - val_loss: 113.9435 - val_mae: 8.9221
# Epoch 13/100
# 13/13 [==============================] - 0s 5ms/step - loss: 63.8364 - mae: 5.6124 - val_loss: 107.7970 - val_mae: 8.4427
# Epoch 14/100
# 13/13 [==============================] - 0s 5ms/step - loss: 61.4788 - mae: 5.6120 - val_loss: 114.3717 - val_mae: 8.6602
# Epoch 15/100
# 13/13 [==============================] - 0s 6ms/step - loss: 59.4354 - mae: 5.3216 - val_loss: 107.0200 - val_mae: 8.0615
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 57.1051 - mae: 5.2832 - val_loss: 108.3423 - val_mae: 8.0199
# Epoch 17/100
# 13/13 [==============================] - 0s 7ms/step - loss: 55.7916 - mae: 5.1370 - val_loss: 103.6999 - val_mae: 7.6185
# Epoch 18/100
# 13/13 [==============================] - 0s 7ms/step - loss: 55.1569 - mae: 5.2155 - val_loss: 103.4115 - val_mae: 7.5389
# Epoch 19/100
# 13/13 [==============================] - 0s 6ms/step - loss: 54.3622 - mae: 4.9610 - val_loss: 116.7131 - val_mae: 8.2102
# Epoch 20/100
# 13/13 [==============================] - 0s 7ms/step - loss: 53.0986 - mae: 5.0363 - val_loss: 99.6790 - val_mae: 7.3072
# Epoch 21/100
# 13/13 [==============================] - 0s 5ms/step - loss: 52.5296 - mae: 5.0462 - val_loss: 105.6576 - val_mae: 7.5963
# Epoch 22/100
# 13/13 [==============================] - 0s 5ms/step - loss: 51.2073 - mae: 4.9442 - val_loss: 100.1586 - val_mae: 7.3593
# Epoch 23/100
# 13/13 [==============================] - 0s 6ms/step - loss: 50.3550 - mae: 4.7302 - val_loss: 92.8498 - val_mae: 7.0292
# Epoch 24/100
# 13/13 [==============================] - 0s 5ms/step - loss: 50.2106 - mae: 4.9376 - val_loss: 93.4251 - val_mae: 7.0963
# Epoch 25/100
# 13/13 [==============================] - 0s 5ms/step - loss: 49.2140 - mae: 4.6684 - val_loss: 98.5534 - val_mae: 7.3655
# Epoch 26/100
# 13/13 [==============================] - 0s 6ms/step - loss: 47.8753 - mae: 4.8280 - val_loss: 84.1546 - val_mae: 6.7183
# Epoch 27/100
# 13/13 [==============================] - 0s 6ms/step - loss: 47.4984 - mae: 4.6329 - val_loss: 89.9767 - val_mae: 7.0374
# Epoch 28/100
# 13/13 [==============================] - 0s 5ms/step - loss: 45.7837 - mae: 4.6178 - val_loss: 80.8840 - val_mae: 6.6260
# Epoch 29/100
# 13/13 [==============================] - 0s 8ms/step - loss: 45.0815 - mae: 4.5323 - val_loss: 87.1192 - val_mae: 6.9608
# Epoch 30/100
# 13/13 [==============================] - 0s 7ms/step - loss: 44.0646 - mae: 4.5952 - val_loss: 78.1334 - val_mae: 6.5562
# Epoch 31/100
# 13/13 [==============================] - 0s 9ms/step - loss: 43.0631 - mae: 4.4385 - val_loss: 75.5281 - val_mae: 6.4585
# Epoch 32/100
# 13/13 [==============================] - 0s 8ms/step - loss: 41.9790 - mae: 4.3819 - val_loss: 71.3815 - val_mae: 6.2838
# Epoch 33/100
# 13/13 [==============================] - 0s 9ms/step - loss: 41.0715 - mae: 4.3795 - val_loss: 72.3136 - val_mae: 6.3634
# Epoch 34/100
# 13/13 [==============================] - 0s 8ms/step - loss: 40.2429 - mae: 4.3000 - val_loss: 69.9501 - val_mae: 6.2606
# Epoch 35/100
# 13/13 [==============================] - 0s 7ms/step - loss: 39.2111 - mae: 4.2721 - val_loss: 62.3013 - val_mae: 5.9209
# Epoch 36/100
# 13/13 [==============================] - 0s 9ms/step - loss: 38.6099 - mae: 4.2607 - val_loss: 59.2526 - val_mae: 5.8355
# Epoch 37/100
# 13/13 [==============================] - 0s 8ms/step - loss: 37.9506 - mae: 4.3874 - val_loss: 54.7680 - val_mae: 5.5874
# Epoch 38/100
# 13/13 [==============================] - 0s 9ms/step - loss: 37.2979 - mae: 4.1874 - val_loss: 52.2459 - val_mae: 5.4060
# Epoch 39/100
# 13/13 [==============================] - 0s 9ms/step - loss: 34.9313 - mae: 3.9621 - val_loss: 53.1080 - val_mae: 5.5085
# Epoch 40/100
# 13/13 [==============================] - 0s 9ms/step - loss: 34.2688 - mae: 3.9865 - val_loss: 53.8616 - val_mae: 5.6189
# Epoch 41/100
# 13/13 [==============================] - 0s 8ms/step - loss: 32.3731 - mae: 3.9417 - val_loss: 48.5378 - val_mae: 5.4233
# Epoch 42/100
# 13/13 [==============================] - 0s 7ms/step - loss: 31.3564 - mae: 3.8426 - val_loss: 47.4562 - val_mae: 5.3150
# Epoch 43/100
# 13/13 [==============================] - 0s 7ms/step - loss: 30.9057 - mae: 3.8231 - val_loss: 46.1214 - val_mae: 5.1962
# Epoch 44/100
# 13/13 [==============================] - 0s 9ms/step - loss: 29.0651 - mae: 3.8186 - val_loss: 44.8367 - val_mae: 5.2298
# Epoch 45/100
# 13/13 [==============================] - 0s 9ms/step - loss: 28.9621 - mae: 3.7436 - val_loss: 42.7757 - val_mae: 5.0376
# Epoch 46/100
# 13/13 [==============================] - 0s 9ms/step - loss: 28.1846 - mae: 3.6265 - val_loss: 41.1575 - val_mae: 4.9041
# Epoch 47/100
# 13/13 [==============================] - 0s 8ms/step - loss: 26.3262 - mae: 3.6145 - val_loss: 42.3595 - val_mae: 5.0864
# Epoch 48/100
# 13/13 [==============================] - 0s 9ms/step - loss: 25.9667 - mae: 3.6717 - val_loss: 45.7464 - val_mae: 5.4471
# Epoch 49/100
# 13/13 [==============================] - 0s 10ms/step - loss: 25.6075 - mae: 3.5495 - val_loss: 40.4346 - val_mae: 4.9095
# Epoch 50/100
# 13/13 [==============================] - 0s 9ms/step - loss: 24.5109 - mae: 3.4852 - val_loss: 38.5048 - val_mae: 4.7912
# Epoch 51/100
# 13/13 [==============================] - 0s 10ms/step - loss: 23.5684 - mae: 3.4492 - val_loss: 40.9108 - val_mae: 5.1115
# Epoch 52/100
# 13/13 [==============================] - 0s 10ms/step - loss: 22.8348 - mae: 3.3797 - val_loss: 36.8907 - val_mae: 4.6904
# Epoch 53/100
# 13/13 [==============================] - 0s 10ms/step - loss: 23.0326 - mae: 3.4329 - val_loss: 39.4917 - val_mae: 5.0142
# Epoch 54/100
# 13/13 [==============================] - 0s 8ms/step - loss: 22.0353 - mae: 3.4629 - val_loss: 46.2469 - val_mae: 5.7266
# Epoch 55/100
# 13/13 [==============================] - 0s 12ms/step - loss: 22.3736 - mae: 3.4100 - val_loss: 43.5982 - val_mae: 5.5159
# Epoch 56/100
# 13/13 [==============================] - 0s 9ms/step - loss: 22.0738 - mae: 3.4075 - val_loss: 36.4781 - val_mae: 4.7015
# Epoch 57/100
# 13/13 [==============================] - 0s 10ms/step - loss: 21.7766 - mae: 3.3588 - val_loss: 38.2715 - val_mae: 4.7589
# Epoch 58/100
# 13/13 [==============================] - 0s 9ms/step - loss: 21.6541 - mae: 3.3349 - val_loss: 38.2611 - val_mae: 4.6084
# Epoch 59/100
# 13/13 [==============================] - 0s 7ms/step - loss: 21.5975 - mae: 3.4048 - val_loss: 37.5742 - val_mae: 4.9709
# Epoch 60/100
# 13/13 [==============================] - 0s 5ms/step - loss: 20.2583 - mae: 3.3211 - val_loss: 39.0583 - val_mae: 5.1737
# Epoch 61/100
# 13/13 [==============================] - 0s 5ms/step - loss: 19.6731 - mae: 3.2242 - val_loss: 38.7366 - val_mae: 5.1783
# Epoch 62/100
# 13/13 [==============================] - 0s 8ms/step - loss: 19.5897 - mae: 3.2029 - val_loss: 40.8352 - val_mae: 5.3581
# Epoch 63/100
# 13/13 [==============================] - 0s 7ms/step - loss: 18.7271 - mae: 3.1743 - val_loss: 38.1600 - val_mae: 5.0592
# Epoch 64/100
# 13/13 [==============================] - 0s 5ms/step - loss: 18.1232 - mae: 3.1365 - val_loss: 36.9077 - val_mae: 5.0344
# Epoch 65/100
# 13/13 [==============================] - 0s 5ms/step - loss: 17.7980 - mae: 3.0832 - val_loss: 35.6727 - val_mae: 4.8114
# Epoch 66/100
# 13/13 [==============================] - 0s 6ms/step - loss: 17.4415 - mae: 3.0563 - val_loss: 34.7248 - val_mae: 4.6409
# Epoch 67/100
# 13/13 [==============================] - 0s 8ms/step - loss: 17.4465 - mae: 3.1101 - val_loss: 37.6182 - val_mae: 5.2069
# Epoch 68/100
# 13/13 [==============================] - 0s 6ms/step - loss: 17.5022 - mae: 3.0411 - val_loss: 34.6389 - val_mae: 4.8667
# Epoch 69/100
# 13/13 [==============================] - 0s 5ms/step - loss: 16.9570 - mae: 3.0680 - val_loss: 38.4478 - val_mae: 5.3155
# Epoch 70/100
# 13/13 [==============================] - 0s 7ms/step - loss: 16.3430 - mae: 3.0211 - val_loss: 39.7456 - val_mae: 5.4590
# Epoch 71/100
# 13/13 [==============================] - 0s 6ms/step - loss: 16.9593 - mae: 3.0087 - val_loss: 32.6145 - val_mae: 4.6883
# Epoch 72/100
# 13/13 [==============================] - 0s 6ms/step - loss: 16.0034 - mae: 2.9541 - val_loss: 32.2735 - val_mae: 4.6503
# Epoch 73/100
# 13/13 [==============================] - 0s 6ms/step - loss: 15.6452 - mae: 2.8994 - val_loss: 33.5176 - val_mae: 4.7593
# Epoch 74/100
# 13/13 [==============================] - 0s 7ms/step - loss: 15.3241 - mae: 2.9039 - val_loss: 30.3641 - val_mae: 4.4702
# Epoch 75/100
# 13/13 [==============================] - 0s 5ms/step - loss: 15.2496 - mae: 2.8972 - val_loss: 32.1859 - val_mae: 4.6608
# Epoch 76/100
# 13/13 [==============================] - 0s 7ms/step - loss: 14.7647 - mae: 2.8061 - val_loss: 29.0951 - val_mae: 4.2432
# Epoch 77/100
# 13/13 [==============================] - 0s 5ms/step - loss: 14.5633 - mae: 2.8223 - val_loss: 33.2754 - val_mae: 4.8675
# Epoch 78/100
# 13/13 [==============================] - 0s 7ms/step - loss: 14.4093 - mae: 2.7828 - val_loss: 34.5473 - val_mae: 5.1536
# Epoch 79/100
# 13/13 [==============================] - 0s 7ms/step - loss: 14.8333 - mae: 2.8870 - val_loss: 34.0881 - val_mae: 5.0682
# Epoch 80/100
# 13/13 [==============================] - 0s 6ms/step - loss: 14.6381 - mae: 2.8083 - val_loss: 32.6043 - val_mae: 4.9408
# Epoch 81/100
# 13/13 [==============================] - 0s 6ms/step - loss: 14.3309 - mae: 2.8112 - val_loss: 31.5523 - val_mae: 4.8306
# Epoch 82/100
# 13/13 [==============================] - 0s 7ms/step - loss: 14.4664 - mae: 2.8377 - val_loss: 27.6714 - val_mae: 4.1420
# Epoch 83/100
# 13/13 [==============================] - 0s 6ms/step - loss: 13.8954 - mae: 2.7283 - val_loss: 29.6693 - val_mae: 4.5048
# Epoch 84/100
# 13/13 [==============================] - 0s 6ms/step - loss: 13.3529 - mae: 2.6726 - val_loss: 27.9490 - val_mae: 4.4501
# Epoch 85/100
# 13/13 [==============================] - 0s 5ms/step - loss: 13.2788 - mae: 2.7105 - val_loss: 30.3837 - val_mae: 4.6750
# Epoch 86/100
# 13/13 [==============================] - 0s 5ms/step - loss: 13.4761 - mae: 2.6754 - val_loss: 28.8814 - val_mae: 4.4705
# Epoch 87/100
# 13/13 [==============================] - 0s 7ms/step - loss: 13.5032 - mae: 2.6970 - val_loss: 25.2914 - val_mae: 3.9376
# Epoch 88/100
# 13/13 [==============================] - 0s 7ms/step - loss: 14.2111 - mae: 2.7969 - val_loss: 29.4397 - val_mae: 4.4412
# Epoch 89/100
# 13/13 [==============================] - 0s 6ms/step - loss: 12.5049 - mae: 2.5821 - val_loss: 25.5352 - val_mae: 4.1894
# Epoch 90/100
# 13/13 [==============================] - 0s 8ms/step - loss: 12.6175 - mae: 2.6277 - val_loss: 28.1433 - val_mae: 4.2628
# Epoch 91/100
# 13/13 [==============================] - 0s 6ms/step - loss: 13.1163 - mae: 2.6547 - val_loss: 25.8180 - val_mae: 4.0050
# Epoch 92/100
# 13/13 [==============================] - 0s 5ms/step - loss: 12.6560 - mae: 2.6170 - val_loss: 27.8148 - val_mae: 4.2511
# Epoch 93/100
# 13/13 [==============================] - 0s 7ms/step - loss: 13.3029 - mae: 2.6702 - val_loss: 26.1678 - val_mae: 3.9388
# Epoch 94/100
# 13/13 [==============================] - 0s 6ms/step - loss: 12.3999 - mae: 2.6035 - val_loss: 26.7612 - val_mae: 4.2591
# Epoch 95/100
# 13/13 [==============================] - 0s 7ms/step - loss: 12.7137 - mae: 2.6438 - val_loss: 27.7240 - val_mae: 4.2777
# Epoch 96/100
# 13/13 [==============================] - 0s 6ms/step - loss: 13.2669 - mae: 2.7221 - val_loss: 25.5657 - val_mae: 4.0772
# Epoch 97/100
# 13/13 [==============================] - 0s 7ms/step - loss: 11.9175 - mae: 2.5383 - val_loss: 29.7273 - val_mae: 4.6317
# Epoch 98/100
# 13/13 [==============================] - 0s 6ms/step - loss: 12.3294 - mae: 2.5897 - val_loss: 27.4558 - val_mae: 4.3189
# Epoch 99/100
# 13/13 [==============================] - 0s 5ms/step - loss: 12.0099 - mae: 2.5277 - val_loss: 29.6131 - val_mae: 4.5037
# Epoch 100/100
# 13/13 [==============================] - 0s 6ms/step - loss: 12.4180 - mae: 2.6141 - val_loss: 32.2256 - val_mae: 4.7756

# %%
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca()
plt.show()

# %%
train_mse=model.evaluate(X_test, y_test, verbose=0)

loss = history.history['loss']
acc = history.history['mae']
val_loss = history.history['val_loss']
val_acc = history.history['val_mae']

epochs = range(1, len(loss)+1)

plt.plot(epochs, acc, 'g*', label='Training MAE')
plt.plot(epochs, val_acc, 'y+', label='Val MAE')
plt.legend()
plt.show()

plt.plot(epochs, loss, 'r*', label='Training loss')
plt.plot(epochs, val_loss, 'b+', label='Val loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Guardar modelo
#
# <center>
#     <b>model.save</b>
# </center>
# </br>
# Guarda la arquitectura, pesos y configuración de entrenamiento del modelo. Los formatos pueden ser:
#
# <ul>
#     <li>HDF5: save_format='h5', nombre sin extensión
#     <li>SavedModel: save_format='tf', nombre con extensión h5
#     <li>Keras
# </ul>
# Mas información en: https://keras.io/api/saving/model_saving_and_loading/

# %%
model.save('number_model.h5', save_format='h5')
# model.save('number_model', save_format='tf')
# model.save('number_model.keras')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### Cargar modelo

# %%
from tensorflow.keras.models import load_model
saved_model = load_model('number_model.h5')

# %% [markdown]
# ### Predicciones
#
# <center>
#     <b>model.predit</b>
# </center>
# </br>
# Retorna las predicciones del conjunto de datos de entrada.

# %%
y_pred = saved_model.predict(X_test_norm)

plt.plot(y_test, color = 'red', label = 'Dato real')
plt.plot(y_pred, color = 'blue', label = 'Dato predicción')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.19130137924758395
